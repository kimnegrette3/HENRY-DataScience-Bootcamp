# %% [markdown]
# # Práctica Clase 6

# %% [markdown]
# 1) Cargar el dataset "Emisiones_CO2.csv" provisto en la clase 2 en un Dataframe de Pandas, quitar los registros que contengan valores faltantes e implementar una nueva columna, que contenga el resultado de una función Hash aplicada sobre el campo "Código de País" y se denomine "Clave_Hash".<br>
# Consideraciones: Se puede utilizar la función provista.

# %%
import pandas as pd

# %%
df = pd.read_csv('Emisiones_CO2.csv',sep='|',decimal=',', encoding='latin-1')
df.head()
# Out:
#   Código de país Nombre del país                   Región   Año CO2 (kt)  \
# 0            ABW           Aruba  América Latina y Caribe  1960      NaN
# 1            ABW           Aruba  América Latina y Caribe  1961      NaN
# 2            ABW           Aruba  América Latina y Caribe  1962      NaN
# 3            ABW           Aruba  América Latina y Caribe  1963      NaN
# 4            ABW           Aruba  América Latina y Caribe  1964      NaN
#
#    CO2 per cápita (toneladas métricas)
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11127 entries, 0 to 11126
# Data columns (total 6 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Código de país                       11127 non-null  object
#  1   Nombre del país                      11127 non-null  object
#  2   Región                               11127 non-null  object
#  3   Año                                  11127 non-null  int64
#  4   CO2 (kt)                             9032 non-null   object
#  5   CO2 per cápita (toneladas métricas)  9029 non-null   float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 521.7+ KB

# %%
#Elimino los puntos en los números y convierto CO2 a float
df['CO2 (kt)'] = df['CO2 (kt)'].str.replace('.', '').str.replace(',','.')
df['CO2 (kt)'] = df['CO2 (kt)'].astype(float)
df['CO2 (kt)'].tail()
# Out:
# 11122    9732.22
# 11123    7682.37
# 11124    8239.75
# 11125    9028.15
# 11126    9860.56
# Name: CO2 (kt), dtype: float64

# %%
df.isna().sum()
# Out:
# Código de país                            0
# Nombre del país                           0
# Región                                    0
# Año                                       0
# CO2 (kt)                               2095
# CO2 per cápita (toneladas métricas)    2098
# dtype: int64

# %%
#Eliminar registros con datos faltantes
df.dropna(inplace=True)
df.shape
# Out:
# (9029, 6)

# %%
def hash_function(key):
    return sum(index * ord(character) for index, character in enumerate(repr(key), start=1))

# %%
df['Clave_Hash'] = df['Código de país'].apply(hash_function)
df.head()
# Out:
#    Código de país Nombre del país                   Región   Año  CO2 (kt)  \
# 26            ABW           Aruba  América Latina y Caribe  1986   179.683
# 27            ABW           Aruba  América Latina y Caribe  1987   447.374
# 28            ABW           Aruba  América Latina y Caribe  1988   612.389
# 29            ABW           Aruba  América Latina y Caribe  1989   649.059
# 30            ABW           Aruba  América Latina y Caribe  1990  1840.830
#
#     CO2 per cápita (toneladas métricas)  Clave_Hash
# 26                             2.868319         910
# 27                             7.234964         910
# 28                            10.026508         910
# 29                            10.634733         910
# 30                            29.620165         910

# %%
df['Clave_Hash']
# Out:
# 26       910
# 27       910
# 28       910
# 29       910
# 30       910
#         ...
# 11122    951
# 11123    951
# 11124    951
# 11125    951
# 11126    951
# Name: Clave_Hash, Length: 9029, dtype: int64

# %%
df[df['Código de país']=='MNE']
# Out:
#      Código de país Nombre del país                 Región   Año  CO2 (kt)  \
# 6805            MNE      Montenegro  Europa y Asia Central  2005   2057.19
# 6806            MNE      Montenegro  Europa y Asia Central  2006   2383.55
# 6807            MNE      Montenegro  Europa y Asia Central  2007   2251.54
# 6808            MNE      Montenegro  Europa y Asia Central  2008   2750.25
# 6809            MNE      Montenegro  Europa y Asia Central  2009   1826.17
# 6810            MNE      Montenegro  Europa y Asia Central  2010   2581.57
# 6811            MNE      Montenegro  Europa y Asia Central  2011   2570.57
#
#       CO2 per cápita (toneladas métricas)  Clave_Hash
# 6805                             3.349044         898
# 6806                             3.875534         898
# 6807                             3.655836         898
# 6808                             4.457679         898
# 6809                             2.953556         898
# ...

# %%
df[df['Código de país']=='SVK']
# Out:
#      Código de país Nombre del país                 Región   Año  CO2 (kt)  \
# 9235            SVK      Eslovaquia  Europa y Asia Central  1992  44183.68
# 9236            SVK      Eslovaquia  Europa y Asia Central  1993  42881.90
# 9237            SVK      Eslovaquia  Europa y Asia Central  1994  40421.34
# 9238            SVK      Eslovaquia  Europa y Asia Central  1995  42115.50
# 9239            SVK      Eslovaquia  Europa y Asia Central  1996  41312.42
# 9240            SVK      Eslovaquia  Europa y Asia Central  1997  41048.40
# 9241            SVK      Eslovaquia  Europa y Asia Central  1998  40480.01
# 9242            SVK      Eslovaquia  Europa y Asia Central  1999  39240.57
# 9243            SVK      Eslovaquia  Europa y Asia Central  2000  35885.26
# 9244            SVK      Eslovaquia  Europa y Asia Central  2001  39357.91
# 9245            SVK      Eslovaquia  Europa y Asia Central  2002  39251.57
# ...

# %% [markdown]
# 2. A partir del Dataframe creado en el punto 1, construir uno nuevo, que contenga solo los valores distintos de la tupla "Clave_Hash", "Código de País" , "Nombre de país" y "Región". Quitando luego del dataframe original los campos "Código de País" , "Nombre de país" y "Región"

# %%
df_new = df.drop_duplicates(subset=['Clave_Hash', 'Código de país', 'Nombre del país', 'Región'])
df_new.shape
# Out:
# (199, 7)

# %%
df = df.drop(columns=['Código de país', 'Nombre del país', 'Región']).reset_index(drop=True)
df.head()
# Out:
#     Año  CO2 (kt)  CO2 per cápita (toneladas métricas)  Clave_Hash
# 0  1986   179.683                             2.868319         910
# 1  1987   447.374                             7.234964         910
# 2  1988   612.389                            10.026508         910
# 3  1989   649.059                            10.634733         910
# 4  1990  1840.830                            29.620165         910

# %%
df.shape
# Out:
# (9029, 4)
